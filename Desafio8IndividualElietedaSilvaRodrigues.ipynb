# %% [markdown]
# <a href="https://colab.research.google.com/github/dsreliete/Womakerscode_DA_desafio_individual/blob/main/Desafio8IndividualElietedaSilvaRodrigues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import statsmodels.formula.api as smf
import statsmodels.api as sm
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import numpy as np
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")

# %%
url = "https://raw.githubusercontent.com/dsreliete/Womakerscode_DA_desafio_individual/refs/heads/main/saude.csv"
df = pd.read_csv(url)

# %%
# 1. Carregar os dados de um arquivo CSV fornecido (saude.csv).
df
# Out:
#    id  age  height  weight gender
# 0   1   23     170      70      M
# 1   2   34     160      65      F
# 2   3   45     175      80      M
# 3   4   25     165      55      F
# 4   5   36     180      90      M
# 5   6   40     170      75      F
# 6   7   29     155      60      F
# 7   8   50     160      85      M
# 8   9   38     175      78      F
# 9  10   28     168      68      M

# %%
# 2. Criar um histograma da variável 'age' usando Matplotlib.

plt.hist(df['age'], bins=10)
plt.xlabel('Idade')
plt.ylabel('Frequencia')
plt.title('Histograma de Idade')
plt.show()

# %%
# 3. Criar um gráfico de dispersão mostrando a relação entre 'height' e 'weight' usando Seaborn.

sns.scatterplot(x='height', y='weight', data=df)
plt.xlabel('Altura')
plt.ylabel('Peso')
plt.title('Gráfico de Dispersão entre Altura e Peso')
plt.show()

# %%
# 4. Criar um gráfico interativo de barras mostrando a contagem de indivíduos por 'gender' usando Plotly.

fig = px.bar(df, x='gender', title='Contagem de Indivíduos por Gênero')
fig.update_layout(xaxis_title='Gênero', yaxis_title='Contagem')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
url = "https://raw.githubusercontent.com/dsreliete/Womakerscode_DA_desafio_individual/refs/heads/main/vendas.csv"
df = pd.read_csv(url)

# %%
# 1. Carregar os dados de um arquivo CSV fornecido (vendas.csv).
df
# Out:
#           date  sales
# 0   2023-01-01    100
# 1   2023-01-02    150
# 2   2023-01-03    200
# 3   2023-01-04    130
# 4   2023-01-05    180
# 5   2023-01-06    220
# 6   2023-01-07    210
# 7   2023-01-08    190
# 8   2023-01-09    170
# 9   2023-01-10    200
# 10  2023-01-11    160
# 11  2023-01-12    210
# 12  2023-01-13    240
# 13  2023-01-14    230
# 14  2023-01-15    220
# 15  2023-01-16    250
# 16  2023-01-17    260
# 17  2023-01-18    270
# 18  2023-01-19    280
# 19  2023-01-20    290
# 20  2023-01-21    300
# 21  2023-01-22    310
# 22  2023-01-23    320
# 23  2023-01-24    330
# 24  2023-01-25    340
# 25  2023-01-26    350
# 26  2023-01-27    360
# 27  2023-01-28    370
# 28  2023-01-29    380
# 29  2023-01-30    390
# 30  2023-01-31    400

# %%
# 2. Criar um gráfico de linhas das vendas ao longo do tempo usando Matplotlib.

df['Date'] = pd.to_datetime(df['date'])
plt.plot(df['date'], df['sales'])
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Linha de vendas ao longo do tempo')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
# 3. Criar um gráfico de decomposição sazonal usando Seaborn.

df['Date'] = pd.to_datetime(df['date'])
df.sort_values('Date', inplace=True)
df.set_index('Date', inplace=True)
decomposition = sm.tsa.seasonal_decompose(df['sales'], model='additive')
fig = decomposition.plot()
fig.set_size_inches(15, 8)
plt.show()

# %%
# 4. Criar um gráfico interativo que permita a exploração dos dados de vendas ao longo do tempo usando Plotly.

df['Date'] = pd.to_datetime(df['date'])
fig = px.line(df, x='date', y='sales', title='Linha de vendas ao longo do tempo')
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
