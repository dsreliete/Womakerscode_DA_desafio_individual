# %% [markdown]
# <a href="https://colab.research.google.com/github/dsreliete/Womakerscode_DA_colab_desafio_ind_panda/blob/main/DesafioIndividualElietedaSilvaRodrigues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/dsreliete/Womakerscode_DA_colab_desafio_ind_panda/main/saude_do_sono_estilo_vida.csv'

df= pd.read_csv(url)
df.head(10)
# Out:
#    ID Gênero  Idade                 Ocupação  Duração do sono  \
# 0   1  Homem     27         Eng. de Software              6.1
# 1   2  Homem     28                Médico(a)              6.2
# 2   3  Homem     28                Médico(a)              6.2
# 3   4  Homem     28  Representante de Vendas              5.9
# 4   5  Homem     28  Representante de Vendas              5.9
# 5   6  Homem     28         Eng. de Software              5.9
# 6   7  Homem     29             Professor(a)              6.3
# 7   8  Homem     29                Médico(a)              7.8
# 8   9  Homem     29                Médico(a)              7.8
# 9  10  Homem     29                Médico(a)              7.8
#
#    Qualidade do sono  Nível de atividade física  Nível de estresse  \
# 0                  6                         42                  6
# 1                  6                         60                  8
# 2                  6                         60                  8
# ...

# %%
#Exercício 1
# Ao visualizar a base você percebeu que seria melhor alterar o nome de algumas colunas. Mude o ‘ID’ para ‘Identificador’, corrija o nome da coluna que indica a pressão sanguínea, mude a coluna ‘Ocupação’ para ‘Profissão’, a coluna ‘Categoria BMI’ está em parte em inglês, substitua para ‘Categoria IMC’.
novas_cols = {'ID': 'Identificador',
              'Pressão sanguíneaaaa': 'Pressão sanguínea',
              'Ocupação': 'Profissão',
              'Categoria BMI': 'Categoria IMC'
              }

df.rename(columns=novas_cols, inplace=True)
df_saude = df.copy()
df_saude.head()
# Out:
#    Identificador Gênero  Idade                Profissão  Duração do sono  \
# 0              1  Homem     27         Eng. de Software              6.1
# 1              2  Homem     28                Médico(a)              6.2
# 2              3  Homem     28                Médico(a)              6.2
# 3              4  Homem     28  Representante de Vendas              5.9
# 4              5  Homem     28  Representante de Vendas              5.9
#
#    Qualidade do sono  Nível de atividade física  Nível de estresse  \
# 0                  6                         42                  6
# 1                  6                         60                  8
# 2                  6                         60                  8
# 3                  4                         30                  8
# 4                  4                         30                  8
#
#   Categoria IMC Pressão sanguínea  Frequência cardíaca  Passos diários  \
# ...

# %%
# Exercício 2
# Qual é a média, a moda e a mediana de horas de sono para cada uma das profissões? [‘mean’, np.median, pd.Series.mod]
df_saude.groupby('Profissão')['Duração do sono'].agg(['mean', 'median', pd.Series.mode])
# Out:
#                              mean  median        mode
# Profissão
# Advogado(a)              7.410638     7.3         7.2
# Cientista                6.000000     6.0  [5.8, 6.2]
# Contador(a)              7.113514     7.2         7.2
# Enfermeiro(a)            7.048611     6.5         6.1
# Eng. de Software         6.750000     6.8         7.5
# Engenheiro(a)            7.987302     8.3         8.4
# Gerente                  6.900000     6.9         6.9
# Médico(a)                6.970423     7.6         6.0
# Pessoa Vendendora        6.403125     6.4         6.5
# Professor(a)             6.690000     6.6         6.6
# Representante de Vendas  5.900000     5.9         5.9

# %%
# Exercício 3
# Das pessoas que atuam com engenharia de software qual a porcentagem de obesos?
total_eng = df_saude.loc[df_saude['Profissão'] == 'Eng. de Software']['Identificador'].count()
total_eng
# Out:
# 4

# %%
# Exercício 3 continuação
df_eng = df_saude.loc[df_saude['Profissão'] == 'Eng. de Software']
total_obes = df_eng[df_eng['Categoria IMC'] == 'Obesidade']['Identificador'].count()
total_obes
# Out:
# 1

# %%
# Exercício 3 continuação
total_obes/total_eng * 100
print('A porcentagem de obesos entre os engenheiros é de ' + str(total_obes/total_eng * 100) + "%")
# Out:
# A porcentagem de obesos entre os engenheiros é de 25.0%

# %%
# Exercício 4
# De acordo com os dados, advogar ou ser representante de vendas faz você dormir menos? (Use o método ‘isin’, considere a média)
df_adv = df_saude[df_saude['Profissão'].isin(['Advogado(a)'])]
adv_mean = df_adv['Duração do sono'].mean()
adv_mean
# Out:
# 7.4106382978723415

# %%
# Exercício 4 continuação
df_rep = df_saude[df_saude['Profissão'].isin(['Representante de Vendas'])]
rep_mean = df_rep['Duração do sono'].mean()
rep_mean
# Out:
# 5.9

# %%
# Exercício 4 continuação
print('A média de duração do sono de um representante de vendas é de ' + str(rep_mean) + 'hs e de um advogado é de ' + str(adv_mean) + ' hs.')
print('Esses resultados sugerem que um representante de vendas dorme menos que um advogado.') if rep_mean < adv_mean else print('Esses resultados sugerem que um advogado dorme menos que um representante de vendas.')
# Out:
# A média de duração do sono de um representante de vendas é de 5.9hs e de um advogado é de 7.4106382978723415 hs.
# Esses resultados sugerem que um representante de vendas dorme menos que um advogado.

# %%
# Exercício 5
# Entre quem fez enfermagem e quem fez medicina, quem tem menos horas de sono? (Use o método ‘isin’, considere a média)
df_enf = df_saude[df_saude['Profissão'].isin(['Enfermeiro(a)'])]
enf_mean = df_enf['Duração do sono'].mean()
enf_mean
# Out:
# 7.048611111111111

# %%
# Exercício 5 continuação
df_med = df_saude[df_saude['Profissão'].isin(['Médico(a)'])]
med_mean = df_med['Duração do sono'].mean()
med_mean
# Out:
# 6.970422535211269

# %%
# Exercício 5 continuação
print('A média de duração do sono de um enfermeiro é de ' + str(enf_mean) + 'hs e de um médico é de ' + str(med_mean) + ' hs.')
response = 'Esses resultados sugerem que um enfermeiro dorme menos que um médico.' if enf_mean < med_mean else 'Esses resultados sugerem que um médico dorme menos que um enfermeiro.'
print(response)
# Out:
# A média de duração do sono de um enfermeiro é de 7.048611111111111hs e de um médico é de 6.970422535211269 hs.
# Esses resultados sugerem que um médico dorme menos que um enfermeiro.

# %%
# Exercício 6
# Faça um subconjunto com as colunas Identificador, Gênero, Idade, Pressão sanguínea e Frequência cardíaca.
df_subconj = df_saude[['Identificador', 'Gênero', 'Idade', 'Pressão sanguínea', 'Frequência cardíaca']]
df_subconj
# Out:
#      Identificador  Gênero  Idade Pressão sanguínea  Frequência cardíaca
# 0                1   Homem     27            126/83                   77
# 1                2   Homem     28            125/80                   75
# 2                3   Homem     28            125/80                   75
# 3                4   Homem     28            140/90                   85
# 4                5   Homem     28            140/90                   85
# ..             ...     ...    ...               ...                  ...
# 368            369  Mulher     59            140/95                   68
# 369            370  Mulher     59            140/95                   68
# 370            371  Mulher     59            140/95                   68
# 371            372  Mulher     59            140/95                   68
# 372            373  Mulher     59            140/95                   68
#
# [373 rows x 5 columns]

# %%
# Exercício 7
# Descubra qual a profissão menos frequente no conjunto. (Use value_counts)
df_saude['Profissão'].value_counts()
# Out:
# Profissão
# Enfermeiro(a)              72
# Médico(a)                  71
# Engenheiro(a)              63
# Advogado(a)                47
# Professor(a)               40
# Contador(a)                37
# Pessoa Vendendora          32
# Eng. de Software            4
# Cientista                   4
# Representante de Vendas     2
# Gerente                     1
# Name: count, dtype: int64

# %%
# Exercício 7 continuação
print('A profissão menos frequente nesse dataframe é gerente')
# Out:
# A profissão menos frequente nesse dataframe é gerente

# %%
# Exercício 8
# Quem tem maior pressão sanguínea média, homens ou mulheres? (Considere a média)

df_saude[['Pressão sistólica', 'Pressão diastólica']] = df_saude['Pressão sanguínea'].str.split('/', expand=True).astype(int)
df_saude['PAM'] = (df_saude['Pressão sistólica'] + 2 * df_saude['Pressão diastólica']) / 3
df_saude
# Out:
#      Identificador  Gênero  Idade                Profissão  Duração do sono  \
# 0                1   Homem     27         Eng. de Software              6.1
# 1                2   Homem     28                Médico(a)              6.2
# 2                3   Homem     28                Médico(a)              6.2
# 3                4   Homem     28  Representante de Vendas              5.9
# 4                5   Homem     28  Representante de Vendas              5.9
# ..             ...     ...    ...                      ...              ...
# 368            369  Mulher     59            Enfermeiro(a)              8.1
# 369            370  Mulher     59            Enfermeiro(a)              8.1
# 370            371  Mulher     59            Enfermeiro(a)              8.0
# 371            372  Mulher     59            Enfermeiro(a)              8.1
# 372            373  Mulher     59            Enfermeiro(a)              8.1
#
# ...

# %%
# Exercício 8 continuação
df_gen = df_saude.set_index('Gênero')
df_mulher = df_gen.loc['Mulher']['PAM'].mean()
df_mulher
# Out:
# 100.89673913043478

# %%
# Exercício 8 continuação
df_homem = df_gen.loc['Homem']['PAM'].mean()
df_homem
# Out:
# 97.65784832451496

# %%
# Exercício 8 continuação
response = 'A pressão sanguínea média das mulheres é maior que a dos homens' if df_mulher > df_homem else 'A pressão sanguínea média dos homens é maior que a das mulheres'
print(response)
# Out:
# A pressão sanguínea média das mulheres é maior que a dos homens

# %%
# Exercício 9
# É predominante entre os participantes dormir 8 horas por dia (considere usar Moda como medida)?
df_sono = df_saude['Duração do sono']
df_sono.mode()[0]
# Out:
# 7.2

# %%
# Exercício 9 continuação
response = 'É predominante entre os participantes dormir 8 horas por dia' if df_sono.mode()[0] == 8 else 'Não é predominante entre os participantes dormir 8 horas por dia'
print(response)
# Out:
# Não é predominante entre os participantes dormir 8 horas por dia

# %%
# Exercício 10
# Pessoas com frequências cardíacas acima de 70 dão mais passos que pessoas com frequência cardíaca menor ou igual a 70? (Use a média)

df_freq_70mais = np.where(df_saude['Frequência cardíaca'] > 70, df_saude['Passos diários'], 0)
df_freq_70mais.mean()
df_freq_70menos = np.where(df_saude['Frequência cardíaca'] <= 70, df_saude['Passos diários'], 0)
df_freq_70menos.mean()

# df_freq_70mais = df_saude.loc[df_saude['Frequência cardíaca'] > 70]['Passos diários']
# df_freq_70menos = df_saude.loc[df_saude['Frequência cardíaca'] < 70]['Passos diários']

result = df_freq_70mais.mean() > df_freq_70menos.mean()
print('A afirmação que Pessoas com frequências cardíacas acima de 70 dão mais passos que pessoas com frequência cardíaca menor ou igual a 70 é ' + str(result))
# Out:
# A afirmação que Pessoas com frequências cardíacas acima de 70 dão mais passos que pessoas com frequência cardíaca menor ou igual a 70 é False

# %%
df_saude.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Identificador              373 non-null    int64
#  1   Gênero                     373 non-null    object
#  2   Idade                      373 non-null    int64
#  3   Profissão                  373 non-null    object
#  4   Duração do sono            373 non-null    float64
#  5   Qualidade do sono          373 non-null    int64
#  6   Nível de atividade física  373 non-null    int64
#  7   Nível de estresse          373 non-null    int64
#  8   Categoria IMC              373 non-null    object
#  9   Pressão sanguínea          373 non-null    object
#  10  Frequência cardíaca        373 non-null    int64
#  11  Passos diários             373 non-null    int64
#  12  Distúrbio do sono          373 non-null    object
# ...
